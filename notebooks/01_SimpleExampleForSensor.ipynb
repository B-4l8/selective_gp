# %%
#%matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns

import torch
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns

import pandas as pd

from torch.utils.data import TensorDataset, DataLoader

# selective_gp 라이브러리에서 필요한 클래스 및 함수 임포트
from selective_gp.datasets.dataset import Dataset

from selective_gp.utils import (
    load_data, get_model, remove_points, fit_layerwise)
from selective_gp.utils.visualization import (
    plot_density, plot_samples, plot_latent)

sns.set(
    font_scale=1.5,
    style="whitegrid",
)
fig_width = 16
# Out:
# c:\Users\imb2a\anaconda3\envs\selective_gp\lib\site-packages\seaborn\rcmod.py:402: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) >= "3.0":
# c:\Users\imb2a\anaconda3\envs\selective_gp\lib\site-packages\setuptools\_distutils\version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)

# %% [markdown]
# $
# \newcommand{\f}{\mathbf{f}}
# \newcommand{\u}{\mathbf{u}}
# \newcommand{\X}{\mathbf{X}}
# \newcommand{\y}{\mathbf{y}}
# \newcommand{\z}{\mathbf{z}}
# \newcommand{\Z}{\mathbf{Z}}
# \renewcommand{\d}{\;\mathrm{d}}
# $
#
# # Introduction
#
# In this notebook we illustrate the concepts laid out in the paper "Probabilistic selection of inducing points in sparse Gaussian processes".
#
# Given a sparse Gausian process (GP) model we consider the problem of identifying a set of inducing points that balances the model complexity (i.e. number of inducing points) against explaining the data. The basic idea is to place a prior on the *selection* of inducing points such that it can be included directly in the Bayesian inference:
#
# $$
# p(\y \mid \X) = \sum_{\Z \in \mathcal{Z}}\left[\int\int p(\y \mid \f)p(\f \mid \u, \X, \Z)p(\u \mid \Z) \d\f\d\u\right]p(\Z)
# $$
#
# Here, $p(\Z)$ is a point process that assigns probability to any given set of inducing points from a given domain, $\mathcal{Z}$. We consider a simple form, that encourages smaller sets of inducing points:
# $$
# p_\alpha(\Z) = -C\exp(-\alpha\lvert \Z \rvert^2).
# $$
# The true posterior over $Z$ is approximated through variational inference. We use as variational distribution a discrete Poisson Point Process (PPP) that assigns independent probability to elements from a pre-defined *candidate* set of points:
# $$
# q_\lambda(\Z) = \prod_{\z_k \in \Z} \lambda_k \prod_{\z_k \notin \Z} (1 - \lambda_k).
# $$

# %% [markdown]
# # SVGP 1D regression
#
# We consider fitting a sparse variational GP (SVGP) to noisy samples drawn from a GP in the range $(0, 50)$. To ensure a setting where some of the initial inducing points do not contribute much and therefore ought to be removed, we make a gap in the data between $x = (15, 35)$ and initialise the inducing inputs over the range $(-10, 60)$.

# %%
# load sensor data

path = r"D:\HDD\PCR_lab\ADD\2025_센서데이터_ADD\ADD 제공데이터\900건+(1)\CEES\EMIM"
df = pd.read_excel(f"{path}/100 sccm CEES_#29_EMIM_12개_221029.xlsx")
# Out:
# c:\Users\imb2a\anaconda3\envs\selective_gp\lib\site-packages\pandas\compat\_optional.py:99: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if distutils.version.LooseVersion(version) < minimum_version:

# %%
plt.plot(df.iloc[:,0], df.iloc[:,1])
plt.axvline(x=60, color = 'r')
plt.show()

# %%
df.index[df.iloc[:, 0] >= 60]
# Out:
# Int64Index([112, 113, 114, 115, 116, 117, 118, 119, 120, 121,
#             ...
#             849, 850, 851, 852, 853, 854, 855, 856, 857, 858],
#            dtype='int64', length=747)

# %%
R0 = df.iloc[:112, 1].mean()
df = (df.iloc[:, 1] - R0) / R0
print(R0)
# Out:
# 2267.7166071428574

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
df = scaler.fit_transform(df.values.reshape(-1,1))

# %%
Y = torch.tensor(df, dtype=torch.float32).reshape(-1, 1)

# X 데이터 추출 (0번째 컬럼이 X라고 가정)
X_numpy = np.arange(1, len(Y) + 1, dtype=np.float32).reshape(-1, 1)
X = torch.from_numpy(X_numpy)

# (만약 X 컬럼이 따로 없다면 아래 주석 해제하여 인덱스 사용)
# X = torch.arange(len(Y), dtype=torch.float32).reshape(-1, 1)

print(f"X shape: {X.shape}, Y shape: {Y.shape}")
# Out:
# X shape: torch.Size([859, 1]), Y shape: torch.Size([859, 1])

# %%
class CustomDataset(Dataset):
    def __init__(self, X, Y, task_type="regression", train_ratio=0.8):
        # 학습/테스트 데이터 분할 (예시: 80%를 학습에 사용)
        n_samples = len(X)
        n_train = int(n_samples * train_ratio)
        
        # 내부 속성(X_train, Y_train 등)에 할당
        self.X_train = X[:n_train]
        self.Y_train = Y[:n_train]
        self.X_test = X[n_train:]
        self.Y_test = Y[n_train:]
        
        # 부모 클래스 초기화 (여기서 self.input_dims가 1로 설정됩니다)
        super().__init__(task_type)

# %%
dataset = CustomDataset(X, Y, task_type="regression")

# %%
# dataset = load_data("synthetic_regression", input_dims=1, seed=5,
#                     n_observations=200, x_min=0, x_max=50, obs_noise=0.1)
# X, Y = dataset.X_train, dataset.Y_train
# M = 50
# mask = ((X < 15) | (35 < X)).flatten()
# X = X[mask]
# Y = Y[mask]

# %%
M = 100
model = get_model(dataset, n_inducing=M, scale_X=False, scale_Y=False)
gp, = model.gps
gp.inducing_inputs = torch.linspace(-10, 60, M)

# %%
def plot_svgp(ax=None):
    if ax is None:
        ax = plt.subplots(figsize=(fig_width, 5))[1]
    ax.set_xlim(-10, 60)
    ax.margins(x=0)
    
    x_in = torch.linspace(-10, 60, 500)
    plot_latent(gp, ax)
    ax.plot(X.flatten(), Y.flatten(), "x", color=plt.cm.Greys(0.9, 0.5))

def plot_probabilities(ax=None):
    if ax is None:
        ax = plt.subplots(figsize=(fig_width, 5))[1]

    with torch.no_grad():
        x_u = gp.inducing_inputs.clone().flatten()
        p = gp.variational_point_process.probabilities

    cm = plt.cm.Set1
    ax.bar(x_u, p, color=cm(0, 0.5), width=2, edgecolor=cm(0))
    ax.set_ylim(0, 1)

# %%
fig, ax = plt.subplots(figsize=(fig_width, 5))
ax.set_title("Observed data")
ax.plot(X.flatten(), Y.flatten(), "x", color=plt.cm.Greys(0.9, 0.5))

# %% [markdown]
# We first fit for 500 epochs to get an approximation of inducing points and hyper-parameters.

# %%
model.fit(X=X, Y=Y, max_epochs=500, var_learning_rate=0.005, hp_learning_rate=0.005)
"""
    def fit(self, max_epochs=500, batch_size=None, verbose=True,
            optimizer="Adam", var_learning_rate=0.02, hp_learning_rate=0.02,
            n_mcmc_samples=1, **observed_values)
"""
plot_svgp()
# Out:
# 100%|██████████| 500/500 [00:15<00:00, 32.07it/s, ELBO=-1.27e+3]

# %% [markdown]
# The black dots are inducing points and the blue line and shading are resp. mean and standard deviation of the SVGP. Note that there are plenty of inducing points that could be removed without much detriment to the predictive posterior, thus decreasing space and time complexity of the model.
#
# To identify these "superfluous" points in a data-driven manner, we estimate the posterior probability of inclusion through score function estimation. While doing so, all other parameters of the model are locked (this restriction could be lifted, but we have opted for a simple implementation that still yields robust results).

# %%
gp.prior_point_process.rate.fill_(1)
gp.variational_point_process.probabilities = 0.3
model.fit_score_function_estimator(
    X=X, Y=Y, learning_rate=0.3, max_epochs=100,
    n_mcmc_samples=8)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(fig_width, 6), sharex=True)
plot_svgp(ax1)
plot_probabilities(ax2)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-2678844942ae> in <module>
#       3 model.fit_score_function_estimator(
#       4     X=X, Y=Y, learning_rate=0.3, max_epochs=100,
# ----> 5     n_mcmc_samples=8)
#       6
#       7 fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(fig_width, 6), sharex=True)
#
# c:\anaconda\selective_gp-master\selective_gp\models\deep_gp_model.py in fit_score_function_estimator(self, X, Y, learning_rate, max_epochs, n_mcmc_samples, verbose)
#     226             learning_rate=learning_rate, n_mcmc_samples=n_mcmc_samples,
#     227             verbose=verbose, callbacks=callbacks,
# --> 228             stop_conditions=self.stop_conditions)
#     229
#     230         if not was_training:
#
# c:\anaconda\selective_gp-master\selective_gp\sfe\score_function_estimator.py in score_function_estimator(objective_function, KL_function, point_processes, learning_rate, max_epochs, n_mcmc_samples, verbose, callbacks, stop_conditions)
#      90             for k in range(n_mcmc_samples):
#      91                 sample_dict = {pp: _sample(pp) for pp in point_processes}
# ---> 92                 bound = objective_function(sample_dict)
#      93
#      94                 bounds.append(bound)
#
# c:\anaconda\selective_gp-master\selective_gp\models\deep_gp_model.py in _likelihood_function(sample_dict)
#     204         def _likelihood_function(sample_dict):
#     205             samples = [sample_dict[pp] for pp in pps]
# --> 206             return self._get_bound_for_point_samples(X, Y, samples)
#     207
#     208         def _KL_function():
#
# c:\anaconda\selective_gp-master\selective_gp\models\deep_gp_model.py in _get_bound_for_point_samples(self, X, Y, samples)
#     179         X_scaled = self.X_scaler.transform(X)
#     180         Y_scaled = self.Y_scaler.transform(Y)
# --> 181         bound = self._log_lik(X=X_scaled, Y=Y_scaled) - self._KL()
#     182
#     183         # Restore parameters
#
# c:\anaconda\selective_gp-master\selective_gp\models\deep_gp_model.py in _log_lik(self, **observed_values)
#      62
#      63         # Get output distribution
# ---> 64         f_dist = self(X, Y=Y)
#      65         assert Y.numel() == f_dist.mean.numel()
#      66
#
# c:\anaconda\selective_gp-master\selective_gp\models\deep_gp_model.py in __call__(self, *args, **kwargs)
#     311
#     312     def __call__(self, *args, **kwargs):
# --> 313         return self.forward(*args, **kwargs)
#
# c:\anaconda\selective_gp-master\selective_gp\models\deep_gp_model.py in forward(self, X, Y)
#     120
#     121             # Get posterior distribution
# --> 122             F = gp(F, Y=Y, likelihood=self.likelihood)
#     123
#     124         if isinstance(self.likelihood, MultitaskGaussianLikelihood):
#
# c:\anaconda\selective_gp-master\selective_gp\layers\svgp.py in __call__(self, X, Y, likelihood, prior)
#     193             res = strat(X, Y, likelihood=likelihood, prior=prior)
#     194         else:
# --> 195             res = strat(X, prior=prior)
#     196
#     197         N, D = len(X), self.output_dims
#
# c:\Users\imb2a\anaconda3\envs\selective_gp\lib\site-packages\gpytorch\variational\_variational_strategy.py in __call__(self, x, prior)
#     125                 inducing_points,
#     126                 inducing_values=variational_dist_u.mean,
# --> 127                 variational_inducing_covar=variational_dist_u.lazy_covariance_matrix,
#     128             )
#     129         elif isinstance(variational_dist_u, Delta):
#
# c:\Users\imb2a\anaconda3\envs\selective_gp\lib\site-packages\gpytorch\module.py in __call__(self, *inputs, **kwargs)
#      26
#      27     def __call__(self, *inputs, **kwargs):
# ---> 28         outputs = self.forward(*inputs, **kwargs)
#      29         if isinstance(outputs, list):
#      30             return [_validate_module_outputs(output) for output in outputs]
#
# c:\Users\imb2a\anaconda3\envs\selective_gp\lib\site-packages\gpytorch\variational\unwhitened_variational_strategy.py in forward(self, x, inducing_points, inducing_values, variational_inducing_covar)
#      61     def forward(self, x, inducing_points, inducing_values, variational_inducing_covar=None):
#      62         # If our points equal the inducing points, we're done
# ---> 63         if torch.equal(x, inducing_points):
#      64             if variational_inducing_covar is None:
#      65                 raise RuntimeError
#
# RuntimeError: Expected object of scalar type float but got scalar type double for argument 'other'

# %% [markdown]
# The lower panel show the probability of inclusion. Although we have only trained for 100 epochs, we already see a tendency to favour inducing points which are located next to the two clusters of data.
#
# We proceed with another 500 epochs to get a more stable estimate.

# %%
model.fit_score_function_estimator(
        X=X, Y=Y, learning_rate=0.3, max_epochs=500,
    n_mcmc_samples=8)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(fig_width, 6), sharex=True)
plot_svgp(ax1)
plot_probabilities(ax2)
# Out:
# 100%|██████████| 500/500 [00:16<00:00, 31.01it/s, ELBO=-91.3]

# %% [markdown]
# At this point, the PPP has locked in on a small subset of points to represent the function. Sampling from the resulting distribution over inducing points and refitting, we arrive at a heavily pruned model.

# %%
remove_points(gp)
gp.variational_point_process.probabilities = 1.0
model.fit(X=X, Y=Y, max_epochs=300)
plot_svgp()
# Out:
# 100%|██████████| 300/300 [00:01<00:00, 178.10it/s, ELBO=52.5]

# %% [markdown]
# ## Changing the prior
#
# In the above example, we arbitrarily set the prior rate, $\alpha$, to 1. This (fixed) hyper-parameter denotes the strength of the prior, meaning that a higher value encourages stronger pruning. A suitable value is situation specific (e.g. are we running the model on a laptop or a GPU-cluster).
#
# If we re-run the above demonstration with a lower prior, we will see that more points remain in the final model.

# %%
# Re-initialise model
model = get_model(dataset, n_inducing=M, scale_X=False, scale_Y=False)
gp, = model.gps
gp.inducing_inputs = torch.linspace(-10, 60, M)
gp.prior_point_process.rate.fill_(5e-2)

print("Pre-fitting")
model.fit(X=X, Y=Y, max_epochs=300)

print("Pruning")
model.fit_score_function_estimator(
    X=X, Y=Y, learning_rate=0.3, max_epochs=500,
    n_mcmc_samples=8)
remove_points(gp)
gp.variational_point_process.probabilities = 1.0

print("Post-fitting")
model.fit(X=X, Y=Y, max_epochs=300)

plot_svgp()
# Out:
# Pre-fitting
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Pruning
# HBox(children=(FloatProgress(value=0.0, max=500.0), HTML(value='')))
# Post-fitting
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
